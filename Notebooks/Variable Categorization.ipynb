# %%
import pandas as pd
import pathlib as Path

address = '../Data/Updated NELA Master Spreadsheet - June 11.xlsx'
excel_file = pd.read_excel(address, sheet_name=None)

# %%
# 2022 Orientation dataframe
orientation_2022_sheet = excel_file['2022 Orientation']
pd.DataFrame(orientation_2022_sheet[['bias']].groupby('bias').value_counts())
# Out:
#                             0
# bias
# center                     18
# conspiracy-pseudoscience  168
# extreme-right               7
# left                       31
# left-bias                   1
# left-center                57
# pro-science                 6
# questionable-source        52
# right                      31
# right-center               21

# %%
# 2021 Orientation dataframe
orientation_2021_sheet = excel_file['2021 Orientation']
pd.DataFrame(orientation_2021_sheet[['Media Bias/Fact Check Label (2021)']].groupby('Media Bias/Fact Check Label (2021)').value_counts())
# Out:
#                                       0
# Media Bias/Fact Check Label (2021)
# center                               14
# conspiracy-pseudoscience            159
# left                                 28
# left-bias                             1
# left-center                          51
# pro-science                           6
# questionable-source                  52
# right                                22
# right-center                         15

# %%
# 2020 Orientation dataframe
orientation_2020_sheet = excel_file['2020 Orientation']
pd.DataFrame(orientation_2020_sheet[['label']].groupby('label').value_counts())
# Out:
#               0
# label
# Mixed       128
# Reliable     97
# Unreliable  111

# %%
# 2019 Orientation dataframe
orientation_2019_sheet = excel_file['2019 Orientation']
pd.DataFrame(orientation_2019_sheet[['Media Bias/Fact Check Label (2019)']].groupby('Media Bias/Fact Check Label (2019)').value_counts())
# Out:
#                                      0
# Media Bias/Fact Check Label (2019)
# conspiracy_pseudoscience            20
# least_biased                         9
# left_bias                           35
# left_center_bias                    45
# questionable_source                 30
# right_bias                          27
# right_center_bias                   17
# satire                              15

# %%
# 2018 Orientation dataframe
orientation_2018_sheet = excel_file['2018 Orientation']
pd.DataFrame(orientation_2018_sheet[['Media Bias/Fact Check Label (2018)']].groupby('Media Bias/Fact Check Label (2018)').value_counts())
# Out:
#                                      0
# Media Bias/Fact Check Label (2018)
# conspiracy_pseudoscience            17
# least_biased                         3
# left_bias                           30
# left_center_bias                    36
# questionable_source                 15
# right_bias                          16
# right_center_bias                   10
# satire                               8
